# %%
# widget-related
import anywidget
import traitlets

# host setting for dev mode
_SS_ = "http://localhost:5175/"

# data prep
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from circuit_data_prep import prepareData

class CircuitViewer(anywidget.AnyWidget):
    _esm = _SS_ + "index.js?anywidget"
    circ = traitlets.Unicode().tag(sync=True)
    mode = traitlets.Unicode("view").tag(sync=True)

def getCircuitViewer(circuit, backend, optimization_level):
    pass_manager = generate_preset_pass_manager(backend=backend, optimization_level=optimization_level, seed_transpiler=1)
    prep = prepareData(circuit, pass_manager, backend)
    circuit_str = prep.toJSON()
    return (CircuitViewer(circ=circuit_str), pass_manager, prep)

# %%
# qiskit circuit & machine
from qiskit import QuantumCircuit
import qiskit_aer
from qiskit_ibm_runtime.fake_provider import FakeVigo
from qiskit.circuit.library import QFT

qft = QFT(5).to_gate()

qcb = QuantumCircuit(5,5)
qcb.append(qft, [0, 1, 2, 3, 4])
qcb.measure_all()

optimization_level = 1
backend = qiskit_aer.AerSimulator.from_backend(FakeVigo())

(viewer, pm, prep_data) = getCircuitViewer(qcb, backend, optimization_level)

# %%
viewer
# Out:
# CircuitViewer(circ='{"original": {"layers": [{"operations": [{"gate": "QFT", "num_qubits": 5, "num_clbits": 0,…

# %%
prep_data.toJSON()
# Out:
# '{"original": {"layers": [{"operations": [{"gate": "QFT", "num_qubits": 5, "num_clbits": 0, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 0}, {"register": {"name": "q", "size": 5}, "index": 1}, {"register": {"name": "q", "size": 5}, "index": 2}, {"register": {"name": "q", "size": 5}, "index": 3}, {"register": {"name": "q", "size": 5}, "index": 4}], "clbits": []}], "num_op": 1}, {"operations": [{"gate": "barrier", "num_qubits": 5, "num_clbits": 0, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 0}, {"register": {"name": "q", "size": 5}, "index": 1}, {"register": {"name": "q", "size": 5}, "index": 2}, {"register": {"name": "q", "size": 5}, "index": 3}, {"register": {"name": "q", "size": 5}, "index": 4}], "clbits": []}], "num_op": 1}, {"operations": [{"gate": "measure", "num_qubits": 1, "num_clbits": 1, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 0}], "clbits": [{"register": {"name": "q", "size": 5}, "index": 0}]}], "num_op": 1}, {"operations": [{"gate": "measure", "num_qubits": 1, "num_clbits": 1, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 1}], "clbits": [{"register": {"name": "q", "size": 5}, "index": 1}]}], "num_op": 1}, {"operations": [{"gate": "measure", "num_qubits": 1, "num_clbits": 1, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 2}], "clbits": [{"register": {"name": "q", "size": 5}, "index": 2}]}], "num_op": 1}, {"operations": [{"gate": "measure", "num_qubits": 1, "num_clbits": 1, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 3}], "clbits": [{"register": {"name": "q", "size": 5}, "index": 3}]}], "num_op": 1}, {"operations": [{"gate": "measure", "num_qubits": 1, "num_clbits": 1, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 4}], "clbits": [{"register": {"name": "q", "size": 5}, "index": 4}]}], "num_op": 1}], "qubits": [{"index": 0, "register": {"name": "q", "size": 5}}, {"index": 1, "register": {"name": "q", "size": 5}}, {"index": 2, "register": {"name": "q", "size": 5}}, {"index": 3, "register": {"name": "q", "size": 5}}, {"index": 4, "register": {"name": "q", "size": 5}}], "clbits": [{"index": 0, "register": {"name": "c", "size": 5}}, {"index": 1, "register": {"name": "c", "size": 5}}, {"index": 2, "register": {"name": "c", "size": 5}}, {"index": 3, "register": {"name": "c", "size": 5}}, {"index": 4, "register": {"name": "c", "size": 5}}, {"index": 0, "register": {"name": "meas", "size": 5}}, {"index": 1, "register": {"name": "meas", "size": 5}}, {"index": 2, "register": {"name": "meas", "size": 5}}, {"index": 3, "register": {"name": "meas", "size": 5}}, {"index": 4, "register": {"name": "meas", "size": 5}}], "num_qubits": 5, "num_clbits": 10, "global_phase": 0}, "transpiled": {"layers": [{"operations": [{"gate": "rz", "num_qubits": 1, "num_clbits": 0, "params": [1.5707963267948966], "qubits": [{"register": {"name": "q", "size": 5}, "index": 1}], "clbits": []}], "num_op": 1, "esp_total": 1, "esp_this": 1, "esp_detail": [{"gate": "rz", "gate_error": 0, "qubits": [1]}]}, {"operations": [{"gate": "sx", "num_qubits": 1, "num_clbits": 0, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 1}], "clbits": []}], "num_op": 1, "esp_total": 0.9994979744441534, "esp_this": 0.9994979744441534, "esp_detail": [{"gate": "sx", "gate_error": 0.0005020255558466025, "qubits": [1]}]}, {"operations": [{"gate": "rz", "num_qubits": 1, "num_clbits": 0, "params": [2.356194490192345], "qubits": [{"register": {"name": "q", "size": 5}, "index": 1}], "clbits": []}], "num_op": 1, "esp_total": 0.9994979744441534, "esp_this": 1, "esp_detail": [{"gate": "rz", "gate_error": 0, "qubits": [1]}]}, {"operations": [{"gate": "cx", "num_qubits": 2, "num_clbits": 0, "params": [], "qubits": [{"register": {"name": "q", "size": 5}, "index": 1}, {"register": {"name": "q", "size": 5}, "index": 3}], "clbits": []}], "num_op": 1, "esp_total": 0.9902055158389522 ...
